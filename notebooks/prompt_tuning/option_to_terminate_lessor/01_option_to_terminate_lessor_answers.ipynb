# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(os.path.join("../../..")))

# %%
import pandas as pd

from notebooks.utils.constants import question_ids_map
from notebooks.utils.simplified_experiment import SimplifiedExperiment

# %% [markdown]
# Retrieve answers file

# %%
answers_df = pd.read_excel("../../../data/asc_842/lease_agreements_info/answers.xlsx")

# %% [markdown]
# Get questions to send to the AI

# %%
question_id = question_ids_map["option_to_terminate_lessor"]

# %%
template_string = """Does the lessor have the right to terminate or cancel the lease prior to the expiration date? Provide the answer in the answer_boolean field.
Context: {context}
"""

# %% [markdown]
# ## Experiment 10:
#
# - gpt-4o-mini
# - text-embedding-3-large
# - structured outputs

# %%
experiment = SimplifiedExperiment(
    answers_df=answers_df,
    question_id=question_id,
    index_name="eafit-text-embedding-3-large",
    csv_results_filename="results/option_to_terminate_lessor_prompt_tuning_v1.csv",
    template_string=template_string,
    retriever_question="What are the termination options for the lessor?",
    use_llm_filter=True,
    boolean_question=True,
)
experiment.run()
# Out:
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: True
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# ...
