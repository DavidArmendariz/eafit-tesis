# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(os.path.join("..")))

# %%
import numpy as np
import pandas as pd
from utils.constants import question_ids_map
from utils.experiment import Experiment
from utils.questions import (
    construct_single_question_for_ai,
)

# %% [markdown]
# Retrieve questions

# %%
questions_df = pd.read_excel("../data/asc_842/grt_ai_reader_questions_v1.xlsx")
questions_df = questions_df.drop(["encoding"], axis=1)
questions_df = questions_df.replace({np.nan: None})

# %% [markdown]
# Retrieve answers file

# %%
answers_df = pd.read_excel("../data/asc_842/lease_agreements_info/answers.xlsx")

# %% [markdown]
# Get questions to send to the AI

# %%
question_id = question_ids_map["option_to_terminate_lessor"]
question_df_filtered = questions_df[questions_df["id"] == question_id]
question_as_json = question_df_filtered.to_dict(orient="records")[0]
question_for_ai = construct_single_question_for_ai(question_as_json)

# %% [markdown]
# ## Experiment 1:
#
# - gpt-3.5-turbo
# - text-embedding-ada-002
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-ada-002",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-ada-002",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment1.csv",
)
experiment.run()
# Out:
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease003: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error decoding JSON: Invalid control character at: line 5 column 26 (char 179)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease004: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease014: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Invalid control character at: line 5 column 27 (char 180)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease025: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease049: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease051: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease062: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease064: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease071: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease073: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease086: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease089: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease095: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.6632653061224489
# Results saved to results/option_to_terminate_lessor_experiment1.csv

# %% [markdown]
# ## Experiment 2:
#
# - gpt-3.5-turbo
# - text-embedding-3-small
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-3-small",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment2.csv",
)
experiment.run()
# Out:
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease002: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease018: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease027: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease029: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease049: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease051: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease057: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease073: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease074: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error processing lease078: '40'
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error processing lease083: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error processing lease085: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease092: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.6836734693877551
# Results saved to results/option_to_terminate_lessor_experiment2.csv

# %% [markdown]
# ## Experiment 3:
#
# - gpt-3.5-turbo
# - text-embedding-3-large
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-3-large",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment3.csv",
)
experiment.run()
# Out:
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease010: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease028: '40'
# Error processing lease029: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease057: '40'
# Error processing lease058: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease064: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease070: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease082: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease086: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Error processing lease087: '40'
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease088: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 10 (char 9)
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease100: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Accuracy: 0.826530612244898
# Results saved to results/option_to_terminate_lessor_experiment3.csv

# %% [markdown]
# ## Experiment 4:
#
# - gpt-3.5-turbo
# - text-embedding-ada-002
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-ada-002",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-ada-002",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment4.csv",
)
experiment.run()
# Out:
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease014: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease023: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease029: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease045: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease049: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease062: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease064: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error processing lease071: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease078: '40'
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease081: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error processing lease089: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Error processing lease095: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.6428571428571429
# Results saved to results/option_to_terminate_lessor_experiment4.csv

# %% [markdown]
# ## Experiment 5:
#
# - gpt-3.5-turbo
# - text-embedding-3-small
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-small",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment5.csv",
)
experiment.run()
# Out:
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease002: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease018: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease038: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease057: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease071: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error processing lease073: '40'
# Error processing lease074: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error processing lease083: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error processing lease085: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Error processing lease087: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.6530612244897959
# Results saved to results/option_to_terminate_lessor_experiment5.csv

# %% [markdown]
# ## Experiment 6:
#
# - gpt-3.5-turbo
# - text-embedding-3-large
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-large",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment6.csv",
)
experiment.run()
# Out:
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease010: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease028: '40'
# Error processing lease029: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# No valid JSON found in the string.
# No answer found
# Answer: None
# Real answer: 1.0
# Error processing lease043: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease057: '40'
# Error processing lease058: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease063: '40'
# Error processing lease064: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease070: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease082: '40'
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Error processing lease088: '40'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.8163265306122449
# Results saved to results/option_to_terminate_lessor_experiment6.csv

# %% [markdown]
# ## Experiment 7:
#
# - gpt-4o-mini
# - text-embedding-3-small
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-mini",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-3-small",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment7.csv",
)
experiment.run()
# Out:
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.6020408163265306
# Results saved to results/option_to_terminate_lessor_experiment7.csv

# %% [markdown]
# ## Experiment 8:
#
# - gpt-4o-mini
# - text-embedding-3-large
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-mini",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-3-large",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment8.csv",
)
experiment.run()
# Out:
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.8469387755102041
# Results saved to results/option_to_terminate_lessor_experiment8.csv

# %% [markdown]
# ## Experiment 9:
#
# - gpt-4o-mini
# - text-embedding-3-small
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-mini",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-small",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment9.csv",
)
experiment.run()
# Out:
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.5918367346938775
# Results saved to results/option_to_terminate_lessor_experiment9.csv

# %% [markdown]
# ## Experiment 10:
#
# - gpt-4o-mini
# - text-embedding-3-large
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-mini",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-large",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment10.csv",
)
experiment.run()
# Out:
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.8775510204081632
# Results saved to results/option_to_terminate_lessor_experiment10.csv

# %% [markdown]
# ## Experiment 11:
#
# - gpt-4o-2024-08-06
# - text-embedding-3-small
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-2024-08-06",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-small",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment11.csv",
)
experiment.run()
# Out:
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 0.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.7653061224489796
# Results saved to results/option_to_terminate_lessor_experiment11.csv

# %% [markdown]
# ## Experiment 12:
#
# - gpt-4o-2024-08-06
# - text-embedding-3-large
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-2024-08-06",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-large",
    boolean_question=True,
    csv_results_filename="results/option_to_terminate_lessor_experiment12.csv",
)
experiment.run()
# Out:
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 0
# Real answer: 1.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 0.0
# Error processing lease076: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 0.0
# INCORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Answer: 1
# Real answer: 1.0
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.9387755102040817
# Results saved to results/option_to_terminate_lessor_experiment12.csv
