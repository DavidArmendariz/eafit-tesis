# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(os.path.join("..")))

# %%
import numpy as np
import pandas as pd
from utils.constants import question_ids_map
from utils.experiment import Experiment
from utils.questions import (
    construct_single_question_for_ai,
)

# %% [markdown]
# Retrieve questions

# %%
questions_df = pd.read_excel("../data/asc_842/grt_ai_reader_questions_v1.xlsx")
questions_df = questions_df.drop(["encoding"], axis=1)
questions_df = questions_df.replace({np.nan: None})

# %% [markdown]
# Retrieve answers file

# %%
answers_df = pd.read_excel("../data/asc_842/lease_agreements_info/answers.xlsx")

# %% [markdown]
# Get questions to send to the AI

# %%
question_id = question_ids_map["effective_date"]
question_df_filtered = questions_df[questions_df["id"] == question_id]
question_as_json = question_df_filtered.to_dict(orient="records")[0]
question_for_ai = construct_single_question_for_ai(question_as_json)

# %% [markdown]
# ## Experiment 1:
#
# - gpt-3.5-turbo
# - text-embedding-ada-002
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-ada-002",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-ada-002",
    date_question=True,
    csv_results_filename="results/effective_date_experiment1.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2024-03-01
# Real answer: 2024-03-01
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2010-07-06
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-11-20
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2010-01-31
# Real answer: 2009-02-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2003-03-21
# Real answer: 2003-03-21
# CORRECT
# ----------------------------------------------------
# Answer: 2018-06-29
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-__-__
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-12-01
# Real answer: 2023-12-01
# CORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2016-03-10
# Real answer: 2016-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-01-26
# Real answer: 2021-01-26
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-22
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2008-01-23
# Real answer: 2020-10-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-04-26
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Error processing lease022: '4'
# Answer: 2007-10-09
# Real answer: 2007-10-09
# CORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-08-09
# Real answer: 2019-08-09
# CORRECT
# ----------------------------------------------------
# Error processing lease027: '4'
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Error processing lease029: '4'
# Answer: 2016-06-20
# Real answer: 2016-06-20
# CORRECT
# ----------------------------------------------------
# Answer: 2022-03-07
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-01-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-02-01
# Real answer: 2022-02-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-08-10
# Real answer: 2022-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-07-15
# Real answer: 2021-07-15
# CORRECT
# ----------------------------------------------------
# Error processing lease038: '4'
# Answer: N/A
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Error processing lease040: '4'
# Answer: 2020-__-__
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Error processing lease042: '4'
# Answer: 2021-04-16
# Real answer: 2021-04-16
# CORRECT
# ----------------------------------------------------
# Answer: 2023-07-01
# Real answer: 2023-07-01
# CORRECT
# ----------------------------------------------------
# Error processing lease045: '4'
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2019-11-01
# Real answer: 2019-11-01
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Error processing lease049: '4'
# Answer: 2020-__-__
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-03-17
# Real answer: 2021-03-17
# CORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Error processing lease057: '4'
# Answer: 2021-01-01
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease059: '4'
# Answer: 2022-01-01
# Real answer: 2022-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Error processing lease066: '4'
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Error processing lease068: '4'
# Answer: 2021-06-10
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-09-01
# Real answer: 2021-02-23
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Error processing lease075: '4'
# Answer: 2019-12-20
# Real answer: 2019-12-20
# CORRECT
# ----------------------------------------------------
# Answer: 2015-10-19
# Real answer: 2015-10-19
# CORRECT
# ----------------------------------------------------
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-10-__
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# Error processing lease088: '4'
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Error processing lease092: '4'
# Answer: 2016-01-01
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Error processing lease095: '4'
# Answer: 2022-01-15
# Real answer: 2020-01-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-09-24
# Real answer: 2021-09-24
# CORRECT
# ----------------------------------------------------
# Error processing lease098: '4'
# Answer: 2021-01-01
# Real answer: 2020-01-09
# INCORRECT
# ----------------------------------------------------
# Error processing lease100: '4'
# Accuracy: 0.43617021276595747
# Results saved to results/effective_date_experiment1.csv

# %% [markdown]
# ## Experiment 2:
#
# - gpt-3.5-turbo
# - text-embedding-3-small
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-3-small",
    date_question=True,
    csv_results_filename="results/effective_date_experiment2.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease003: '4'
# Answer: 2010-04-02
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-11-20
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2009-02-10
# Real answer: 2009-02-10
# CORRECT
# ----------------------------------------------------
# Error processing lease008: '4'
# Error processing lease010: '4'
# Answer: 2020-__-__
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-01-01
# Real answer: 2023-12-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2016-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Error processing lease018: '4'
# Error processing lease020: '4'
# Answer: 2007-04-27
# Real answer: 2007-04-27
# CORRECT
# ----------------------------------------------------
# Answer: 202_
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-09-28
# Real answer: 2007-10-09
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Error processing lease027: '4'
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Error processing lease029: '4'
# Error processing lease030: '4'
# Error processing lease031: '4'
# Answer: 2022-01-01
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Error processing lease033: '4'
# Answer: 2022-01-05
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-08-04
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Error processing lease037: '4'
# Answer: 2021-01-14
# Real answer: 2021-01-14
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-24
# Real answer: 2021-09-24
# CORRECT
# ----------------------------------------------------
# Error processing lease040: '4'
# Error processing lease041: '4'
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-01
# Real answer: 2021-04-16
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-07-01
# Real answer: 2023-07-01
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-29
# Real answer: 2020-01-29
# CORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Error processing lease047: '4'
# Answer: 2022-10-07
# Real answer: 2022-10-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease049: '4'
# Error processing lease050: '4'
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Error processing lease052: '4'
# Answer: 2022-01-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-03-17
# Real answer: 2021-03-17
# CORRECT
# ----------------------------------------------------
# Error processing lease055: '4'
# Answer: 2029-08-01
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-01
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease059: '4'
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Error decoding JSON: Expecting ',' delimiter: line 1 column 9 (char 8)
# No answer found
# Answer: None
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Error processing lease063: '4'
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Error processing lease065: '4'
# Error processing lease066: '4'
# Error processing lease067: '4'
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2021-06-10
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-09-01
# Real answer: 2021-02-23
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Error processing lease074: '4'
# Error processing lease075: '4'
# Answer: 2022-01-01
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# Error processing lease077: '4'
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Error processing lease081: '4'
# Answer: 2022-01-01
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-10-19
# Real answer: 2015-10-19
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Error processing lease094: '4'
# Answer: 2021-07-19
# Real answer: 2021-07-19
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2020-01-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Error processing lease098: '4'
# Answer: 2020-01-09
# Real answer: 2020-01-09
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.3191489361702128
# Results saved to results/effective_date_experiment2.csv

# %% [markdown]
# ## Experiment 3:
#
# - gpt-3.5-turbo
# - text-embedding-3-large
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-3-large",
    date_question=True,
    csv_results_filename="results/effective_date_experiment3.csv",
)
experiment.run()
# Out:
# Error processing lease001: '4'
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2010-10-01
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-05-01
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-01-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease007: '4'
# Answer: 2003-11-01
# Real answer: 2003-03-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-06-29
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: 2027-02-28
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease012: '4'
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-02
# Real answer: 2023-12-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease015: '4'
# Answer: 2016-04-01
# Real answer: 2016-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2008-01-23
# Real answer: 2020-10-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Answer: 202_
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Error processing lease023: '4'
# Answer: 2023-11-01
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease026: '4'
# Error processing lease027: '4'
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Error processing lease029: '4'
# Answer: 2022-01-01
# Real answer: 2016-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease032: '4'
# Answer: 2022-01-31
# Real answer: 2022-01-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-11-01
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Error processing lease037: '4'
# Answer: 2021-12-01
# Real answer: 2021-01-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 20____
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 20____
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-04-15
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-04-16
# Real answer: 2021-04-16
# CORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2023-07-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-02-01
# Real answer: 2020-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-10-30
# Real answer: 2019-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Error processing lease049: '4'
# Answer: 2020-__-__
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease051: '4'
# Error processing lease052: '4'
# Answer: N/A
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-06-01
# Real answer: 2021-03-17
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Error processing lease058: '4'
# Answer: 2006-05-19
# Real answer: 2006-05-19
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2022-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Error processing lease068: '4'
# Answer: 2021-01-06
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Error processing lease070: '4'
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease072: '4'
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 201_
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-02-26
# Real answer: 2021-02-26
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Error processing lease084: '4'
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2022-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Error processing lease092: '4'
# Answer: N/A
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Answer: 2021-07-19
# Real answer: 2021-07-19
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2020-01-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-03-30
# Real answer: 2020-03-30
# CORRECT
# ----------------------------------------------------
# Error processing lease099: '4'
# Error processing lease100: '4'
# Accuracy: 0.24468085106382978
# Results saved to results/effective_date_experiment3.csv

# %% [markdown]
# ## Experiment 4:
#
# - gpt-3.5-turbo
# - text-embedding-ada-002
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-ada-002",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-ada-002",
    date_question=True,
    csv_results_filename="results/effective_date_experiment4.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2024-03-01
# Real answer: 2024-03-01
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2010-07-06
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-11-20
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease007: '4'
# Error processing lease008: '4'
# Answer: 2018-06-05
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-__-__
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Error processing lease014: '4'
# Error processing lease015: '4'
# Answer: 2016-03-10
# Real answer: 2016-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-01-26
# Real answer: 2021-01-26
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-22
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2008-01-23
# Real answer: 2020-10-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-04-26
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-__-__
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-10-09
# Real answer: 2007-10-09
# CORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-08-09
# Real answer: 2019-08-09
# CORRECT
# ----------------------------------------------------
# Error processing lease027: '4'
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-08-30
# Real answer: 2017-07-11
# INCORRECT
# ----------------------------------------------------
# Error processing lease030: Request timed out.
# Answer: 2022-03-07
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-01-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-02-01
# Real answer: 2022-02-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-08-10
# Real answer: 2022-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-07-15
# Real answer: 2021-07-15
# CORRECT
# ----------------------------------------------------
# No valid JSON found in the string.
# No answer found
# Answer: None
# Real answer: 2021-01-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-__-__
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Error processing lease041: '4'
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-04-16
# Real answer: 2021-04-16
# CORRECT
# ----------------------------------------------------
# Answer: 2023-07-01
# Real answer: 2023-07-01
# CORRECT
# ----------------------------------------------------
# Error processing lease045: '4'
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2019-11-01
# Real answer: 2019-11-01
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Error processing lease049: '4'
# Answer: 2020-__-__
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-03-17
# Real answer: 2021-03-17
# CORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Error processing lease057: '4'
# Answer: 2021-01-01
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2006-05-19
# Real answer: 2006-05-19
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Error processing lease066: '4'
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Answer: 2029-11-01
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-06-10
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-09-01
# Real answer: 2021-02-23
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Error processing lease075: '4'
# Answer: 2019-12-20
# Real answer: 2019-12-20
# CORRECT
# ----------------------------------------------------
# Error processing lease077: '4'
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Error processing lease082: '4'
# Answer: 2015-10-__
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# No valid JSON found in the string.
# No answer found
# Answer: None
# Real answer: 2022-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Error processing lease092: '4'
# Answer: 2016-01-01
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Error processing lease095: '4'
# Answer: 2022-01-15
# Real answer: 2020-01-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-09-24
# Real answer: 2021-09-24
# CORRECT
# ----------------------------------------------------
# Error processing lease098: '4'
# Answer: 2021-01-01
# Real answer: 2020-01-09
# INCORRECT
# ----------------------------------------------------
# Error processing lease100: '4'
# Accuracy: 0.4148936170212766
# Results saved to results/effective_date_experiment4.csv

# %% [markdown]
# ## Experiment 5:
#
# - gpt-3.5-turbo
# - text-embedding-3-small
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-small",
    date_question=True,
    csv_results_filename="results/effective_date_experiment5.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease003: '4'
# Answer: 2010-04-02
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-11-20
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2009-02-10
# Real answer: 2009-02-10
# CORRECT
# ----------------------------------------------------
# Error processing lease008: '4'
# Answer: 2018-06-29
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-__-__
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease012: '4'
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-01-01
# Real answer: 2023-12-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2016-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Error processing lease018: '4'
# No valid JSON found in the string.
# No answer found
# Answer: None
# Real answer: 2020-10-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-04-27
# Real answer: 2007-04-27
# CORRECT
# ----------------------------------------------------
# Error processing lease022: '4'
# Answer: 2007-09-28
# Real answer: 2007-10-09
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Error processing lease027: '4'
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Error processing lease029: '4'
# Error processing lease030: '4'
# Error processing lease031: '4'
# Answer: 2022-01-01
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Error processing lease033: '4'
# Answer: 2022-01-05
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease036: '4'
# Error processing lease037: '4'
# Answer: 2021-01-14
# Real answer: 2021-01-14
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-24
# Real answer: 2021-09-24
# CORRECT
# ----------------------------------------------------
# Error processing lease040: '4'
# Answer: 20__
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-01
# Real answer: 2021-04-16
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-07-01
# Real answer: 2023-07-01
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-29
# Real answer: 2020-01-29
# CORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Error processing lease047: '4'
# Answer: 2022-10-07
# Real answer: 2022-10-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease049: '4'
# Error processing lease050: '4'
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-03-17
# Real answer: 2021-03-17
# CORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2029-08-01
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-01
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease059: '4'
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Error processing lease061: '4'
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Error processing lease063: '4'
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Error processing lease065: '4'
# Error processing lease066: '4'
# Error processing lease067: '4'
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2021-06-10
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Error processing lease070: '4'
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Error processing lease075: '4'
# Answer: 2022-01-01
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# Error processing lease077: '4'
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Error processing lease081: '4'
# Answer: 2022-01-01
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Error processing lease084: '4'
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# No valid JSON found in the string.
# No answer found
# Answer: None
# Real answer: 2022-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Error processing lease094: '4'
# Answer: 2021-07-19
# Real answer: 2021-07-19
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2020-01-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-03-30
# Real answer: 2020-03-30
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-09
# Real answer: 2020-01-09
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.3404255319148936
# Results saved to results/effective_date_experiment5.csv

# %% [markdown]
# ## Experiment 6:
#
# - gpt-3.5-turbo
# - text-embedding-3-large
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-3.5-turbo",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-large",
    date_question=True,
    csv_results_filename="results/effective_date_experiment6.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2016-02-28
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-05-01
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-01-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Error processing lease007: '4'
# Answer: 2003-11-01
# Real answer: 2003-03-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-06-29
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: 2027-02-28
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Error processing lease014: '4'
# Error processing lease015: '4'
# Answer: 2016-04-01
# Real answer: 2016-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2008-01-23
# Real answer: 2020-10-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Answer: 202__-__-__
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-20-20
# Real answer: 2007-10-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-11-01
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Error processing lease027: '4'
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Error processing lease029: '4'
# Answer: 2022-01-01
# Real answer: 2016-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-04-03
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-01-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Error processing lease037: '4'
# Answer: 2021-12-01
# Real answer: 2021-01-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 20____
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 20____
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-04-16
# Real answer: 2021-04-16
# CORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2023-07-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-02-01
# Real answer: 2020-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-10-30
# Real answer: 2019-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Error processing lease049: '4'
# Answer: 2020-__-__
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Error processing lease052: '4'
# Answer: N/A
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-06-01
# Real answer: 2021-03-17
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Error processing lease058: '4'
# Error processing lease059: '4'
# Answer: 2022-01-01
# Real answer: 2022-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Error processing lease068: '4'
# Answer: 2021-01-06
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Error processing lease070: '4'
# No valid JSON found in the string.
# No answer found
# Answer: None
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# No valid JSON found in the string.
# No answer found
# Answer: None
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# No valid JSON found in the string.
# No answer found
# Answer: None
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-02-26
# Real answer: 2021-02-26
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-15
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Error processing lease084: '4'
# Error processing lease085: '4'
# Error processing lease086: '4'
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# No valid JSON found in the string.
# No answer found
# Answer: None
# Real answer: 2022-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer: N/A
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Error processing lease092: '4'
# Answer: N/A
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Answer: 2021-07-19
# Real answer: 2021-07-19
# CORRECT
# ----------------------------------------------------
# Error processing lease096: '4'
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-03-30
# Real answer: 2020-03-30
# CORRECT
# ----------------------------------------------------
# Error processing lease099: '4'
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.23404255319148937
# Results saved to results/effective_date_experiment6.csv

# %% [markdown]
# ## Experiment 7:
#
# - gpt-4o-mini
# - text-embedding-3-small
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-mini",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-3-small",
    date_question=True,
    csv_results_filename="results/effective_date_experiment7.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-25
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2010-07-06
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-11-20
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2009-02-10
# Real answer: 2009-02-10
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2003-03-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-06-29
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-27
# Real answer: 2023-12-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2016-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2007-04-26
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-09-28
# Real answer: 2007-10-09
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2006-05-30
# Real answer: 2006-05-30
# CORRECT
# ----------------------------------------------------
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2017-07-11
# INCORRECT
# ----------------------------------------------------
# Answer: 2016-06-20
# Real answer: 2016-06-20
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-05
# Real answer: 2022-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-08-04
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-08-01
# Real answer: 2021-07-15
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-01-14
# Real answer: 2021-01-14
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-24
# Real answer: 2021-09-24
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-01
# Real answer: 2021-04-16
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-07-01
# Real answer: 2023-07-01
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-29
# Real answer: 2020-01-29
# CORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2019-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2012-02-01
# Real answer: 2012-12-13
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-03-17
# Real answer: 2021-03-17
# CORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-01
# Real answer: 2021-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2006-05-19
# Real answer: 2006-05-19
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-06
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-09-01
# Real answer: 2021-02-23
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-10-19
# Real answer: 2015-10-19
# CORRECT
# ----------------------------------------------------
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-10-19
# Real answer: 2015-10-19
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Answer: 2021-07-19
# Real answer: 2021-07-19
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2020-01-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-03-30
# Real answer: 2020-03-30
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-09
# Real answer: 2020-01-09
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.5
# Results saved to results/effective_date_experiment7.csv

# %% [markdown]
# ## Experiment 8:
#
# - gpt-4o-mini
# - text-embedding-3-large
# - unstructured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-mini",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=False,
    index_name="eafit-text-embedding-3-large",
    date_question=True,
    csv_results_filename="results/effective_date_experiment8.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2010-10-01
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2005-04-05
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2009-02-10
# Real answer: 2009-02-10
# CORRECT
# ----------------------------------------------------
# Answer: 2003-11-01
# Real answer: 2003-03-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-06-29
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2012-04-16
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2023-12-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2016-04-01
# Real answer: 2016-04-01
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2008-01-23
# Real answer: 2020-10-01
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2007-10-09
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2006-05-30
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-01
# Real answer: 2017-07-11
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2016-06-20
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-05
# Real answer: 2022-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-11-01
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-08-01
# Real answer: 2021-07-15
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-01-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-04-16
# Real answer: 2021-04-16
# CORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2023-07-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-02-01
# Real answer: 2020-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-10-30
# Real answer: 2019-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2012-02-01
# Real answer: 2012-12-13
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-06-01
# Real answer: 2021-03-17
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2019-12-31
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-01
# Real answer: 2021-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2006-05-19
# Real answer: 2006-05-19
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-06
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-09-01
# Real answer: 2021-02-23
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-__-__
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-12-15
# Real answer: 2021-02-26
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2016-05-01
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-12-15
# Real answer: 2021-02-26
# INCORRECT
# ----------------------------------------------------
# Answer:
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Answer: 2021-07-19
# Real answer: 2021-07-19
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2020-01-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-03-30
# Real answer: 2020-03-30
# CORRECT
# ----------------------------------------------------
# Answer: 2020-02-01
# Real answer: 2020-01-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.32978723404255317
# Results saved to results/effective_date_experiment8.csv

# %% [markdown]
# ## Experiment 9:
#
# - gpt-4o-mini
# - text-embedding-3-small
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-mini",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-small",
    date_question=True,
    csv_results_filename="results/effective_date_experiment9.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-25
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2010-04-02
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-11-20
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2009-02-10
# Real answer: 2009-02-10
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2003-03-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-06-29
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: 20__-__-__
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-27
# Real answer: 2023-12-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer: YYYY-MM-DD
# Real answer: 2016-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-28
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2007-04-26
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-10-09
# Real answer: 2007-10-09
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2006-05-30
# Real answer: 2006-05-30
# CORRECT
# ----------------------------------------------------
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2017-07-11
# INCORRECT
# ----------------------------------------------------
# Answer: 2016-06-20
# Real answer: 2016-06-20
# CORRECT
# ----------------------------------------------------
# Answer: YYYY-MM-DD
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-05
# Real answer: 2022-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-08-04
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-07-15
# Real answer: 2021-07-15
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-14
# Real answer: 2021-01-14
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-24
# Real answer: 2021-09-24
# CORRECT
# ----------------------------------------------------
# Answer: 20__-__-__
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 20__-__-__
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-01
# Real answer: 2021-04-16
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-07-01
# Real answer: 2023-07-01
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-29
# Real answer: 2020-01-29
# CORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2023-01-01
# Real answer: 2019-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2012-02-01
# Real answer: 2012-12-13
# INCORRECT
# ----------------------------------------------------
# Answer: 201_
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-03-17
# Real answer: 2021-03-17
# CORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-01
# Real answer: 2021-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2006-05-19
# Real answer: 2006-05-19
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-06
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-09-01
# Real answer: 2021-02-23
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-11
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-10-19
# Real answer: 2015-10-19
# CORRECT
# ----------------------------------------------------
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-10-19
# Real answer: 2015-10-19
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2016-01-01
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Answer: 2021-07-19
# Real answer: 2021-07-19
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2020-01-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-03-30
# Real answer: 2020-03-30
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-09
# Real answer: 2020-01-09
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.5212765957446809
# Results saved to results/effective_date_experiment9.csv

# %% [markdown]
# ## Experiment 10:
#
# - gpt-4o-mini
# - text-embedding-3-large
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-mini",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-large",
    date_question=True,
    csv_results_filename="results/effective_date_experiment10.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2010-10-01
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2005-04-05
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: YYYY-MM-DD
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2009-02-10
# Real answer: 2009-02-10
# CORRECT
# ----------------------------------------------------
# Answer: 2003-11-01
# Real answer: 2003-03-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-06-29
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-02-28
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: YYYY-MM-DD
# Real answer: 2023-12-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2016-04-01
# Real answer: 2016-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2008-01-23
# Real answer: 2020-10-01
# INCORRECT
# ----------------------------------------------------
# Answer: null
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Answer: 202_
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: YYYY-MM-DD
# Real answer: 2007-10-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2033-11-01
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2006-05-30
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-01
# Real answer: 2017-07-11
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2016-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 20___-__-__
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: ____-__-__
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-01-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-11-01
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-07-06
# Real answer: 2021-07-15
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-01-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 20__-__-__
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 20__-__-__
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-04-16
# Real answer: 2021-04-16
# CORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2023-07-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-02-01
# Real answer: 2020-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-10-30
# Real answer: 2019-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2012-02-01
# Real answer: 2012-12-13
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer: YYYY-MM-DD
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-06-01
# Real answer: 2021-03-17
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-01
# Real answer: 2021-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2006-05-19
# Real answer: 2006-05-19
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-06
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-09-01
# Real answer: 2021-02-23
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-11
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-__-__
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-12-15
# Real answer: 2021-02-26
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-19
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2016-05-01
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-12-15
# Real answer: 2021-02-26
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Answer: 2021-07-19
# Real answer: 2021-07-19
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2020-01-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-03-30
# Real answer: 2020-03-30
# CORRECT
# ----------------------------------------------------
# Answer: 2020-02-01
# Real answer: 2020-01-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.35106382978723405
# Results saved to results/effective_date_experiment10.csv

# %% [markdown]
# ## Experiment 11:
#
# - gpt-4o-2024-08-06
# - text-embedding-3-small
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-2024-08-06",
    embedding_model="text-embedding-3-small",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-small",
    date_question=True,
    csv_results_filename="results/effective_date_experiment11.csv",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-11
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2010-07-06
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-11-20
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-28
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2009-02-10
# Real answer: 2009-02-10
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2003-03-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-06-05
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-27
# Real answer: 2023-12-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2016-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2007-04-27
# Real answer: 2007-04-27
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-09-28
# Real answer: 2007-10-09
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2006-05-30
# Real answer: 2006-05-30
# CORRECT
# ----------------------------------------------------
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2017-07-11
# INCORRECT
# ----------------------------------------------------
# Answer: 2016-06-20
# Real answer: 2016-06-20
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-01-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-08-04
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-08-01
# Real answer: 2021-07-15
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-01-14
# Real answer: 2021-01-14
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-24
# Real answer: 2021-09-24
# CORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: None
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-06-15
# Real answer: 2021-04-16
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-07-01
# Real answer: 2023-07-01
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-29
# Real answer: 2020-01-29
# CORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2025-01-01
# Real answer: 2019-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2012-02-01
# Real answer: 2012-12-13
# INCORRECT
# ----------------------------------------------------
# Answer: 201_
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-28
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-03-17
# Real answer: 2021-03-17
# CORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2017-02-02
# Real answer: 2017-02-02
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-01
# Real answer: 2021-09-01
# CORRECT
# ----------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 12
#       1 experiment = Experiment(
#       2     answers_df=answers_df,
#       3     question_id=question_id,
#    (...)
#      10     csv_results_filename="results/effective_date_experiment11.csv",
#      11 )
# ---> 12 experiment.run()
#
# File ~/eafit/eafit-tesis/notebooks/utils/experiment.py:103, in Experiment.run(self)
#     100 self.lease_number = number
#     102 try:
# --> 103     result = process_lease(
#     104         file_name=file_name,
#     105         namespace=namespace,
#     106         question_for_ai=self.question_for_ai,
#     107         question_id=self.question_id,
#     108         answers_df=self.answers_df,
#     109         model=self.model,
#     110         embedding_model=self.embedding_model,
#     111         use_structured_outputs=self.use_structured_outputs,
#     112         index_name=self.index_name,
#     113     )
#     114     answer = result["answer"]
#     115     real_answer_unprocessed = result["real_answer_unprocessed"]
#
# File ~/eafit/eafit-tesis/notebooks/utils/process_lease.py:22, in process_lease(file_name, namespace, question_for_ai, question_id, answers_df, index_name, model, embedding_model, use_structured_outputs)
#      11 def process_lease(
#      12     file_name: str,
#      13     namespace: str,
#    (...)
#      20     use_structured_outputs=False,
#      21 ):
# ---> 22     answer_from_ai = get_answer_from_ai(
#      23         json.dumps(question_for_ai),
#      24         namespace,
#      25         model=model,
#      26         embedding_model=embedding_model,
#      27         supports_structured_output=use_structured_outputs,
#      28         index_name=index_name,
#      29     )
#      30     question_id_str = f"{question_id}"
#      31     answers_for_lease_df = answers_df[answers_df["Lease"] == file_name][question_id]
#
# File ~/eafit/eafit-tesis/notebooks/utils/ai.py:48, in get_answer_from_ai(questions, namespace, index_name, model, embedding_model, supports_structured_output)
#      35         llm = ChatOpenAI(model=model, temperature=0)
#      37     question_answerer = QuestionAnswerer(
#      38         vectorstore=PineconeVectorStore(
#      39             index_name=index_name,
#    (...)
#      46         model=model,
#      47     )
# ---> 48     answer = question_answerer.process_answer(questions)
#      49     return answer
#      50 except Exception as e:
#
# File ~/eafit/eafit-tesis/openai_pinecone/services/question_answerer.py:51, in QuestionAnswerer.process_answer(self, question)
#      46 else:
#      47     rag_chain = (
#      48         retrieve_context | self.prompt_template | llm | StrOutputParser()
#      49     )
# ---> 51 return rag_chain.invoke(question)
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:3022, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3020             input = context.run(step.invoke, input, config, **kwargs)
#    3021         else:
# -> 3022             input = context.run(step.invoke, input, config)
#    3023 # finish the root run
#    3024 except BaseException as e:
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:5343, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5337 def invoke(
#    5338     self,
#    5339     input: Input,
#    5340     config: Optional[RunnableConfig] = None,
#    5341     **kwargs: Optional[Any],
#    5342 ) -> Output:
# -> 5343     return self.bound.invoke(
#    5344         input,
#    5345         self._merge_configs(config),
#    5346         **{**self.kwargs, **kwargs},
#    5347     )
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:784, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     776 def generate_prompt(
#     777     self,
#     778     prompts: list[PromptValue],
#    (...)
#     781     **kwargs: Any,
#     782 ) -> LLMResult:
#     783     prompt_messages = [p.to_messages() for p in prompts]
# --> 784     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:641, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     639         if run_managers:
#     640             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 641         raise e
#     642 flattened_outputs = [
#     643     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     644     for res in results
#     645 ]
#     646 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:631, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     628 for i, m in enumerate(messages):
#     629     try:
#     630         results.append(
# --> 631             self._generate_with_cache(
#     632                 m,
#     633                 stop=stop,
#     634                 run_manager=run_managers[i] if run_managers else None,
#     635                 **kwargs,
#     636             )
#     637         )
#     638     except BaseException as e:
#     639         if run_managers:
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:853, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     851 else:
#     852     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 853         result = self._generate(
#     854             messages, stop=stop, run_manager=run_manager, **kwargs
#     855         )
#     856     else:
#     857         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:682, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     677         warnings.warn(
#     678             "Cannot currently include response headers when response_format is "
#     679             "specified."
#     680         )
#     681     payload.pop("stream")
# --> 682     response = self.root_client.beta.chat.completions.parse(**payload)
#     683 elif self.include_response_headers:
#     684     raw_response = self.client.with_raw_response.create(**payload)
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/openai/resources/beta/chat/completions.py:116, in Completions.parse(self, messages, model, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, seed, service_tier, stop, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     109 _validate_input_tools(tools)
#     111 extra_headers = {
#     112     "X-Stainless-Helper-Method": "beta.chat.completions.parse",
#     113     **(extra_headers or {}),
#     114 }
# --> 116 raw_completion = self._client.chat.completions.create(
#     117     messages=messages,
#     118     model=model,
#     119     response_format=_type_to_response_format(response_format),
#     120     frequency_penalty=frequency_penalty,
#     121     function_call=function_call,
#     122     functions=functions,
#     123     logit_bias=logit_bias,
#     124     logprobs=logprobs,
#     125     max_completion_tokens=max_completion_tokens,
#     126     max_tokens=max_tokens,
#     127     n=n,
#     128     parallel_tool_calls=parallel_tool_calls,
#     129     presence_penalty=presence_penalty,
#     130     seed=seed,
#     131     service_tier=service_tier,
#     132     stop=stop,
#     133     stream_options=stream_options,
#     134     temperature=temperature,
#     135     tool_choice=tool_choice,
#     136     tools=tools,
#     137     top_logprobs=top_logprobs,
#     138     top_p=top_p,
#     139     user=user,
#     140     extra_headers=extra_headers,
#     141     extra_query=extra_query,
#     142     extra_body=extra_body,
#     143     timeout=timeout,
#     144 )
#     145 return _parse_chat_completion(
#     146     response_format=response_format,
#     147     chat_completion=raw_completion,
#     148     input_tools=tools,
#     149 )
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/openai/resources/chat/completions.py:704, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     668 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     669 def create(
#     670     self,
#    (...)
#     701     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     702 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     703     validate_response_format(response_format)
# --> 704     return self._post(
#     705         "/chat/completions",
#     706         body=maybe_transform(
#     707             {
#     708                 "messages": messages,
#     709                 "model": model,
#     710                 "frequency_penalty": frequency_penalty,
#     711                 "function_call": function_call,
#     712                 "functions": functions,
#     713                 "logit_bias": logit_bias,
#     714                 "logprobs": logprobs,
#     715                 "max_completion_tokens": max_completion_tokens,
#     716                 "max_tokens": max_tokens,
#     717                 "n": n,
#     718                 "parallel_tool_calls": parallel_tool_calls,
#     719                 "presence_penalty": presence_penalty,
#     720                 "response_format": response_format,
#     721                 "seed": seed,
#     722                 "service_tier": service_tier,
#     723                 "stop": stop,
#     724                 "stream": stream,
#     725                 "stream_options": stream_options,
#     726                 "temperature": temperature,
#     727                 "tool_choice": tool_choice,
#     728                 "tools": tools,
#     729                 "top_logprobs": top_logprobs,
#     730                 "top_p": top_p,
#     731                 "user": user,
#     732             },
#     733             completion_create_params.CompletionCreateParams,
#     734         ),
#     735         options=make_request_options(
#     736             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     737         ),
#     738         cast_to=ChatCompletion,
#     739         stream=stream or False,
#     740         stream_cls=Stream[ChatCompletionChunk],
#     741     )
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/openai/_base_client.py:1270, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1256 def post(
#    1257     self,
#    1258     path: str,
#    (...)
#    1265     stream_cls: type[_StreamT] | None = None,
#    1266 ) -> ResponseT | _StreamT:
#    1267     opts = FinalRequestOptions.construct(
#    1268         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1269     )
# -> 1270     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/openai/_base_client.py:947, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     944 else:
#     945     retries_taken = 0
# --> 947 return self._request(
#     948     cast_to=cast_to,
#     949     options=options,
#     950     stream=stream,
#     951     stream_cls=stream_cls,
#     952     retries_taken=retries_taken,
#     953 )
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/openai/_base_client.py:983, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     980 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     982 try:
# --> 983     response = self._client.send(
#     984         request,
#     985         stream=stream or self._should_stream_response_body(request=request),
#     986         **kwargs,
#     987     )
#     988 except httpx.TimeoutException as err:
#     989     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/eafit/eafit-tesis/.venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/Library/Application Support/pdm/python/cpython@3.11.8/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~/Library/Application Support/pdm/python/cpython@3.11.8/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Experiment 12:
#
# - gpt-4o-2024-08-06
# - text-embedding-3-large
# - structured outputs

# %%
experiment = Experiment(
    answers_df=answers_df,
    question_id=question_id,
    question_for_ai=question_for_ai,
    model="gpt-4o-2024-08-06",
    embedding_model="text-embedding-3-large",
    use_structured_outputs=True,
    index_name="eafit-text-embedding-3-large",
    date_question=True,
    csv_results_filename="results/effective_date_experiment12.csv",
)
experiment.run()
# Out:
# Answer: Kyle J. Beller
# Real answer: BarBell Real Estate, LLC
# INCORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is not explicitly mentioned in the provided source document.
# Real answer: Sony Chocolate Industries Ltd
# INCORRECT
# ----------------------------------------------------
# Error processing lease003: 'NoneType' object is not subscriptable
# Answer: Venable Tenant, LLC
# Real answer: Venable Tenant, LLC
# CORRECT
# ----------------------------------------------------
# Error processing lease005: 'NoneType' object is not subscriptable
# Answer: The name of the lessor is not explicitly mentioned in the provided Source Document.
# Real answer: Hooten Non Exempt Family Trust B
# INCORRECT
# ----------------------------------------------------
# Answer: Landlord
# Real answer: AR Industrial No. 1, Ltd
# INCORRECT
# ----------------------------------------------------
# Answer: Village Corner, LLC
# Real answer: Village Corner, LLC
# CORRECT
# ----------------------------------------------------
# Answer: Blackstone Dry Lease Agreement
# Real answer: GH4 Partners LLC
# INCORRECT
# ----------------------------------------------------
# Error processing lease010: 'NoneType' object is not subscriptable
# Answer: Holder Investments, Inc.
# Real answer: Holder Investments, Inc
# CORRECT
# ----------------------------------------------------
# Answer: Orwig Property Management Center Square, LLC
# Real answer: ORWIG PROPERTY MANAGEMENT CENTER SQUARE LLC
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is not explicitly mentioned in the provided Source Document.
# Real answer: Douglas R. Rippel
# INCORRECT
# ----------------------------------------------------
# Error processing lease014: 'NoneType' object is not subscriptable
# Error processing lease015: 'NoneType' object is not subscriptable
# Answer: Exponent Realty, LLC
# Real answer: EXPONENT REALTY, LLC
# CORRECT
# ----------------------------------------------------
# Error processing lease017: 'NoneType' object is not subscriptable
# Answer: The name of the lessor is "Ground Lessor".
# Real answer: BOYER RESEARCH PARK ASSOCIATES X, L.C.
# INCORRECT
# ----------------------------------------------------
# Answer: PAB
# Real answer: Chicago Executive Airport
# INCORRECT
# ----------------------------------------------------
# Answer: Up 64 Sidney Street, LLC
# Real answer: UP 64 SIDNEY STREET, LLC
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is "Landlord".
# Real answer: INDUSTRIAL DEVELOPMENTS INTERNATIONAL, INC.
# INCORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is "Building 1 (AOTC) / Kymera Therapeutics, Inc."
# Real answer: ARE-MA REGION NO. 75, LLC
# INCORRECT
# ----------------------------------------------------
# Error processing lease023: 'NoneType' object is not subscriptable
# Answer: Owner
# Real answer: APT Cowork, LLC
# INCORRECT
# ----------------------------------------------------
# Error processing lease025: 'NoneType' object is not subscriptable
# Error processing lease026: 'NoneType' object is not subscriptable
# Error processing lease027: 'NoneType' object is not subscriptable
# Answer: Industria Asociadas Maquiladoras, S. A. de C. V.
# Real answer: Industrias Asociadas Maquiladoras, S.A. de C.V.
# CORRECT
# ----------------------------------------------------
# Answer: Gleiss Lutz
# Real answer: fischer group SE & Co. KG
# INCORRECT
# ----------------------------------------------------
# Answer: Eagle 1 Investments, L.L.C.
# Real answer: Eagle I Investments, L.L.C.
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is Oak Street Real Estate Capital, LLC.
# Real answer: CTROOK002 LLC
# INCORRECT
# ----------------------------------------------------
# Answer: Dan Tsang and Dan Stoddard
# Real answer: ARE-SAN FRANCISCO NO. 63, LLC
# INCORRECT
# ----------------------------------------------------
# Answer: Landa Properties LLC
# Real answer: Landa Properties LLC
# CORRECT
# ----------------------------------------------------
# Answer: Landa App LLC - 1703 Summerwoods Lane Griffin GA LLC
# Real answer: Landa App LLC - 1703 Summerwoods Lane Griffin GA LLC
# CORRECT
# ----------------------------------------------------
# Answer: Landa Properties LLC
# Real answer: Landa Properties LLC
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is not explicitly mentioned in the provided source document.
# Real answer: PINAL COUNTY
# INCORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is Anthony Nigel Sampson.
# Real answer: Anthony Nigel Sampson
# INCORRECT
# ----------------------------------------------------
# Answer: ARE-SD Region No. 71, LLC
# Real answer: ARE-SD REGION NO. 71, LLC
# CORRECT
# ----------------------------------------------------
# Answer: Cargill, Incorporated
# Real answer: CARGILL, INCORPORATED
# CORRECT
# ----------------------------------------------------
# Error processing lease040: 'NoneType' object is not subscriptable
# Error processing lease041: 'NoneType' object is not subscriptable
# Answer: 100 Chesapeake Blvd LLC
# Real answer: 100 CHESAPEAKE BLVD LLC
# CORRECT
# ----------------------------------------------------
# Error processing lease043: 'NoneType' object is not subscriptable
# Answer: Wisconsin Fertility and Reproductive Associates, S.C.
# Real answer: Taylyn Holdings, LLC
# INCORRECT
# ----------------------------------------------------
# Answer: Minoan Capital Pty Ltd
# Real answer: MINOAN CAPITAL PTY LTD
# CORRECT
# ----------------------------------------------------
# Answer: Clene Nanomedicine, Inc.
# Real answer: UPPER CHEASPEAKE FLEX ONE, LLC
# INCORRECT
# ----------------------------------------------------
# Answer: Apple Moving, Inc.
# Real answer: Apple Moving, Inc.
# CORRECT
# ----------------------------------------------------
# Answer: Landlord
# Real answer: Sunrise Nominee Trust
# INCORRECT
# ----------------------------------------------------
# Answer: Cruiser Lane, LLC
# Real answer: Cruiser Lane, LLC
# CORRECT
# ----------------------------------------------------
# Error processing lease050: 'NoneType' object is not subscriptable
# Answer: Phil Bosua
# Real answer: Phil Bosua
# CORRECT
# ----------------------------------------------------
# Answer: Visions Federal Credit Union
# Real answer: VISIONS FEDERAL CREDIT UNION
# CORRECT
# ----------------------------------------------------
# Answer: Hooten Non Exempt Family Trust B
# Real answer: Hooten Non Exempt Family Trust B
# CORRECT
# ----------------------------------------------------
# Answer: Lessor
# Real answer: Trustmark National Bank
# INCORRECT
# ----------------------------------------------------
# Answer: Price-Poore House, LLC
# Real answer: Price-Poore House, LLC
# CORRECT
# ----------------------------------------------------
# Answer: State of Wyoming
# Real answer: State of Wyoming
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is Queen Mary and Westfield College, University of London.
# Real answer: Queen Mary Bioenterprises Limited
# INCORRECT
# ----------------------------------------------------
# Answer: Sichuan Anyi Hengke Technology Co., Ltd.
# Real answer: Sichuan Anyi Hengke Technology Co., Ltd.
# CORRECT
# ----------------------------------------------------
# Error processing lease059: 'NoneType' object is not subscriptable
# Answer: The name of the lessor is not explicitly mentioned in the provided Source Document.
# Real answer: Kathryn Joy Atkinson
# INCORRECT
# ----------------------------------------------------
# Answer: Overlook At Rob Roy Owner (Delaware), LLC
# Real answer: Overlook At Rob Roy Owner, LLC
# CORRECT
# ----------------------------------------------------
# Answer: Phil Bosua
# Real answer: Phil Bosua
# CORRECT
# ----------------------------------------------------
# Answer: Hangzhou Zhexin Information Technology Co., LTD
# Real answer: Hangzhou Zhexin Information Technology Co., LTD
# CORRECT
# ----------------------------------------------------
# Answer: Beijing Guochuan Borui Technology Co., Ltd.
# Real answer: Beijing Guochuan Borui Technology Co., Ltd.
# CORRECT
# ----------------------------------------------------
# Answer: Beijing Guochuan Borui Technology Co., Ltd.
# Real answer: Beijing Guochuan Borui Technology Co., Ltd.
# CORRECT
# ----------------------------------------------------
# Answer: State of Wyoming
# Real answer: STATE OF WYOMING
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is not explicitly mentioned in the provided Source Document.
# Real answer: McCLELLAN FARM
# INCORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is State of Wyoming.
# Real answer: STATE OF WYOMING
# INCORRECT
# ----------------------------------------------------
# Answer: 105 W First Street Owner, L.L.C.
# Real answer: 105 W. First Street Owner, L.L.C.
# CORRECT
# ----------------------------------------------------
# Answer: Mundo Talio SL
# Real answer: Mundo Talio SL
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is Steven Atkinson.
# Real answer: Steven and Janet Atkinson
# INCORRECT
# ----------------------------------------------------
# Answer: Kathryn Atkinson
# Real answer: Kathryn Joy Atkinson
# CORRECT
# ----------------------------------------------------
# Answer: ALC Aircraft Limited
# Real answer: ALC Aircraft Limited
# CORRECT
# ----------------------------------------------------
# Error processing lease074: 'NoneType' object is not subscriptable
# Answer: RFR Commercial
# Real answer: HP LUMINA, LLC
# INCORRECT
# ----------------------------------------------------
# Answer: E. & E. McLaughlin Ltd.
# Real answer: TARGET GROUP INC.
# INCORRECT
# ----------------------------------------------------
# Answer: Malone Rte 2 Waterbury Properties, LLC
# Real answer: MALONE US ROUTE 2 WATERBURY PROPERTIES, LLC
# CORRECT
# ----------------------------------------------------
# Answer: Rehco Holdings, LLC
# Real answer: Rehco Holdings, LLC
# CORRECT
# ----------------------------------------------------
# Answer: Ever Winland Limited
# Real answer: Ever Winland Limited
# CORRECT
# ----------------------------------------------------
# Error processing lease080: 'NoneType' object is not subscriptable
# Answer: VT Aviation Leasing LLC
# Real answer: VT Aviation Leasing LLC
# CORRECT
# ----------------------------------------------------
# Answer: VT Equipment Leasing LLC
# Real answer: VT Equipment Leasing LLC
# CORRECT
# ----------------------------------------------------
# Answer: Rehco Holdings, LLC
# Real answer: Rehco Holdings, LLC
# CORRECT
# ----------------------------------------------------
# Answer: Malone Rte 2 Waterbury Properties, LLC
# Real answer: MALONE US ROUTE 2 WATERBURY PROPERTIES, LLC
# CORRECT
# ----------------------------------------------------
# Answer: Le-Mar Holdings, Inc.
# Real answer: HP LUMINA, LLC
# INCORRECT
# ----------------------------------------------------
# Answer: ALC Aircraft Limited
# Real answer: ALC Aircraft Limited
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is ALC Aircraft Limited.
# Real answer: ALC Aircraft Limited
# INCORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is not explicitly mentioned in the provided Source Document.
# Real answer: Steven and Janet Atkinso
# INCORRECT
# ----------------------------------------------------
# Answer: Queen Mary Bioenterprises Limited
# Real answer: Queen Mary Bioenterprises Limited
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is not explicitly mentioned in the provided Source Document.
# Real answer: Ailanthus L.L.C.
# INCORRECT
# ----------------------------------------------------
# Answer: Westwind Acquisition Company, LLC.
# Real answer: WESTWIND ACQUISITION COMPANY, L.L.C.
# CORRECT
# ----------------------------------------------------
# Answer: Ever Winland Limited
# Real answer: Ever Winland Limited
# CORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is "Landlord."
# Real answer: Penta Partners, LLC
# INCORRECT
# ----------------------------------------------------
# Answer: The name of the lessor is V G Instruments Group Limited.
# Real answer: THE COUNCIL OF THE CITY OF MANCHESTER
# INCORRECT
# ----------------------------------------------------
# Answer: Arve Ulriksen
# Real answer: Mo Industripark AS
# INCORRECT
# ----------------------------------------------------
# Answer: Landlord
# Real answer: UCB, INC.
# INCORRECT
# ----------------------------------------------------
# Answer: Cargill, Incorporated
# Real answer: CARGILL, INCORPORATED
# CORRECT
# ----------------------------------------------------
# Answer: Beijing Hontao Management Consulting Co., Ltd.
# Real answer: Beijing Hontao Management Consulting Co., Ltd.
# CORRECT
# ----------------------------------------------------
# Answer: Wickfield Properties LLC
# Real answer: Wickfield Phoenix LLC
# CORRECT
# ----------------------------------------------------
# Error processing lease100: 'NoneType' object is not subscriptable
# Accuracy: 0.47
# Results saved to results/lessor_name_experiment12.csv
