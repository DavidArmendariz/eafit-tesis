# %%
import PyPDF2
from transformers import BertTokenizerFast, BertForTokenClassification
import torch

# %%
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        for page in reader.pages:
            text += page.extract_text()
    return text

# %%
# Replace with your model's Hugging Face repository name
repo_name = "darmendarizp/eafit-ner-v1"

# Load the tokenizer and model from the Hugging Face Model Hub
tokenizer = BertTokenizerFast.from_pretrained(repo_name)
model = BertForTokenClassification.from_pretrained(repo_name)
# Out:
# /home/david/grt/grt_reader/.venv/lib/python3.11/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
def get_companies(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)
    # Tokenize the PDF text
    tokens = tokenizer(pdf_text.split(), return_tensors="pt", is_split_into_words=True, truncation=True, padding=True)
    
    # Get predictions from the model
    with torch.no_grad():
        outputs = model(**tokens)
        predictions = torch.argmax(outputs.logits, dim=2)
    
    # Convert predictions to label IDs
    predicted_labels = predictions[0].tolist()
    
    # Get the labels and corresponding tokens
    labels = [model.config.id2label[label_id] for label_id in predicted_labels]
    tokens_list = tokens.tokens()
    
    # Extract company names based on the 'ORG' label
    company_names = []
    current_company = []

    for token, label in zip(tokens_list, labels):
        if label == 'B-ORG' or label == 'I-ORG':
            current_company.append(token)
        else:
            if current_company:
                company_names.append(" ".join(current_company))
                current_company = []
    # Add the last company name if there's one left
    if current_company:
        company_names.append(" ".join(current_company))
    print("Companies found:", company_names)

# %%
numbers = [f"{i:03}" for i in range(1, 101)]
for i in numbers:
    pdf_path = f"../../data/asc_842/lease_agreements/lease{i}.pdf"
    print(f"Extracting companies from {pdf_path}")
    get_companies(pdf_path)
    print("\n")
# Out:
# Extracting companies from ../../data/asc_842/lease_agreements/lease001.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease002.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease003.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease004.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease005.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease006.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease007.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease008.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease009.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease010.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease011.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease012.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease013.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease014.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease015.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease016.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease017.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease018.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease019.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease020.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease021.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease022.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease023.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease024.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease025.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease026.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease027.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease028.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease029.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease030.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease031.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease032.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease033.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease034.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease035.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease036.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease037.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease038.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease039.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease040.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease041.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease042.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease043.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease044.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease045.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease046.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease047.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease048.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease049.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease050.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease051.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease052.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease053.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease054.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease055.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease056.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease057.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease058.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease059.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease060.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease061.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease062.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease063.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease064.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease065.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease066.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease067.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease068.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease069.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease070.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease071.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease072.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease073.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease074.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease075.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease076.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease077.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease078.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease079.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease080.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease081.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease082.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease083.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease084.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease085.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease086.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease087.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease088.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease089.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease090.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease091.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease092.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease093.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease094.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease095.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease096.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease097.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease098.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease099.pdf
# Companies found: []
#
#
# Extracting companies from ../../data/asc_842/lease_agreements/lease100.pdf
# Companies found: []
