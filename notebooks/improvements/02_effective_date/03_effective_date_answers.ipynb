# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(os.path.join("../../..")))

# %%
import pandas as pd

from notebooks.utils.constants import question_ids_map
from notebooks.utils.simplified_experiment import SimplifiedExperiment

# %% [markdown]
# Retrieve answers file

# %%
train_dataset = pd.read_excel("../../aggregated_results/train_dataset.xlsx")
test_dataset = pd.read_excel("../../aggregated_results/test_dataset.xlsx")
answers_df_train = pd.read_excel(
    "../../../data/asc_842/lease_agreements_info/answers.xlsx"
)
answers_df_train = answers_df_train.iloc[train_dataset["Lease"] - 1]
answers_df_test = pd.read_excel(
    "../../../data/asc_842/lease_agreements_info/answers.xlsx"
)
answers_df_test = answers_df_test.iloc[test_dataset["Lease"] - 1]

# %% [markdown]
# Get questions to send to the AI

# %%
question_id = question_ids_map["effective_date"]

# %%
template_string = """What is the effective date of the contract?
In other words: on what date was the contract executed?
This could be the date the document was signed, or if that date is unavailable it's
the date on which the agreement was entered into or is dated.
Provide the answer in the answer_date field in the format YYYY-MM-DD.
Context: {context}
"""

# %% [markdown]
# ## Variant 3
#
# - gpt-4o-mini
# - text-embedding-3-large
# - structured outputs

# %%
experiment = SimplifiedExperiment(
    answers_df=answers_df_train,
    question_id=question_id,
    index_name="eafit-text-embedding-3-large",
    date_question=True,
    csv_results_filename="results/effective_date_prompt_tuning_train_v3.csv",
    template_string=template_string,
    retriever_question="What are all the dates in this document?",
    use_llm_filter=True,
    numbers_list=[str(i).zfill(3) for i in (answers_df_train.index + 1).to_list()],
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2023-11-22
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-05-01
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-05-01
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2009-02-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2003-03-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-06-29
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-10-01
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2023-12-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2016-04-01
# Real answer: 2016-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2007-10-01
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-10-09
# Real answer: 2007-10-09
# CORRECT
# ----------------------------------------------------
# Answer: 2022-11-01
# Real answer: 2022-11-01
# CORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2006-05-30
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-08-30
# Real answer: 2017-07-11
# INCORRECT
# ----------------------------------------------------
# Answer: 2016-09-01
# Real answer: 2016-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-01
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: ____-__-__
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-31
# Real answer: 2022-01-31
# CORRECT
# ----------------------------------------------------
# Answer: 2022-01-05
# Real answer: 2022-02-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-07-15
# Real answer: 2021-07-15
# CORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-01-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-06-01
# Real answer: 2021-04-16
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2023-07-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-01-28
# Real answer: 2020-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-11-01
# Real answer: 2019-11-01
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2012-02-01
# Real answer: 2012-12-13
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-02-01
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer: 2021-08-01
# Real answer: 2021-08-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-06-01
# Real answer: 2021-03-17
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2019-08-02
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-01
# Real answer: 2021-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2006-05-19
# Real answer: 2006-05-19
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Answer: 2019-11-02
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-01-06
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-09-01
# Real answer: 2021-02-23
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2018-06-28
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-01-01
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-12-15
# Real answer: 2021-02-26
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-10-31
# Real answer: 2019-10-31
# CORRECT
# ----------------------------------------------------
# Answer: 2021-12-21
# Real answer: 2021-12-21
# CORRECT
# ----------------------------------------------------
# Answer: 2021-12-21
# Real answer: 2021-12-21
# CORRECT
# ----------------------------------------------------
# Answer: 2015-10-01
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-02-14
# Real answer: 2023-02-14
# CORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2019-11-01
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-12-15
# Real answer: 2021-02-26
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-01-01
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Answer: 2021-07-19
# Real answer: 2021-07-19
# CORRECT
# ----------------------------------------------------
# Answer: 2020-01-01
# Real answer: 2020-01-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-03-30
# Real answer: 2020-03-30
# CORRECT
# ----------------------------------------------------
# Answer: 2020-02-01
# Real answer: 2020-01-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.40425531914893614
# Results saved to results/effective_date_prompt_tuning_v3.csv

# %%
experiment = SimplifiedExperiment(
    answers_df=answers_df_test,
    question_id=question_id,
    index_name="eafit-text-embedding-3-large",
    date_question=True,
    csv_results_filename="results/effective_date_prompt_tuning_test_v3.csv",
    template_string=template_string,
    retriever_question="What are all the dates in this document?",
    use_llm_filter=True,
    numbers_list=[str(i).zfill(3) for i in (answers_df_test.index + 1).to_list()],
)
experiment.run()
