# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(os.path.join("../../..")))

# %%
import pandas as pd

from notebooks.utils.constants import question_ids_map
from notebooks.utils.simplified_experiment import SimplifiedExperiment

# %% [markdown]
# Retrieve answers file

# %%
answers_df = pd.read_excel("../../../data/asc_842/lease_agreements_info/answers.xlsx")

# %% [markdown]
# Get questions to send to the AI

# %%
question_id = question_ids_map["effective_date"]

# %%
template_string = """
Please review the contract details provided and answer the following question:

**Question**: What is the effective date of the contract?

**Instructions**:
1. **Identify the signature date**: Begin by checking the contract for a specific signature date. This is often listed near the end of the document, alongside the parties' signatures. If this date is present, it should generally be considered the effective date.
2. **Check for an explicitly stated effective date**: If the contract does not have a signature date or it is unclear, look for any explicitly stated "effective date" or "date of execution" within the contract text, which may sometimes be noted at the beginning or in an introductory section.
3. **Determine fallback date**: If neither a signature date nor an explicit effective date is provided, identify any other date that indicates when the agreement was entered into, such as a date mentioned in the title or heading.
4. **Confirm and record the date**: Once the effective date is identified, verify that it is in the correct format. Enter the answer in the `answer_date` field in the format YYYY-MM-DD.

**Context**: {context}
"""

# %% [markdown]
# ## Variation 4
#
# - gpt-4o-mini
# - text-embedding-3-large
# - structured outputs

# %%
experiment = SimplifiedExperiment(
    answers_df=answers_df,
    question_id=question_id,
    index_name="eafit-text-embedding-3-large",
    date_question=True,
    csv_results_filename="results/effective_date_prompt_tuning_v4.csv",
    template_string=template_string,
    retriever_question="What is the effective date of the contract, or the date on which the contract was signed or entered into?",
    use_llm_filter=True,
    chunks_filename="chunks/effective_date_chunks_v4.txt",
)
experiment.run()
# Out:
# Answer: 2022-01-25
# Real answer: 2022-01-25
# CORRECT
# ----------------------------------------------------
# Answer: 2024-03-01
# Real answer: 2024-03-01
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-05-01
# Real answer: 2015-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2000-06-15
# Real answer: 1995-03-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2009-02-10
# Real answer: 2009-02-10
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2003-03-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-06-05
# Real answer: 2018-07-05
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2024-03-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2015-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-16
# Real answer: 2017-01-28
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-12-01
# Real answer: 2023-12-01
# CORRECT
# ----------------------------------------------------
# Answer: 2017-04-01
# Real answer: 2017-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2016-04-01
# Real answer: 2016-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-05-01
# Real answer: 2021-01-26
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2019-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2020-10-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-04-26
# Real answer: 2007-04-27
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2007-10-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2022-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-09-01
# Real answer: 2019-08-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2006-05-30
# INCORRECT
# ----------------------------------------------------
# Answer: 2007-09-01
# Real answer: 2007-09-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-09-01
# Real answer: 2017-07-11
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2016-06-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-03-14
# Real answer: 2022-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2019-12-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-01-05
# Real answer: 2022-01-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-02-01
# Real answer: 2022-02-01
# CORRECT
# ----------------------------------------------------
# Answer: 2021-10-29
# Real answer: 2021-11-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2022-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2018-08-01
# Real answer: 2021-07-15
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-01-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-10-04
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-08-10
# Real answer: 2021-08-10
# CORRECT
# ----------------------------------------------------
# Answer: 2021-04-16
# Real answer: 2021-04-16
# CORRECT
# ----------------------------------------------------
# Answer: 2020-10-01
# Real answer: 2023-07-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-02-01
# Real answer: 2020-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-01
# Real answer: 2021-08-10
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-11-01
# Real answer: 2019-11-01
# CORRECT
# ----------------------------------------------------
# Answer: 2022-10-01
# Real answer: 2022-10-01
# CORRECT
# ----------------------------------------------------
# Answer: 2012-12-13
# Real answer: 2012-12-13
# CORRECT
# ----------------------------------------------------
# Answer: 2022-02-01
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2022-12-07
# Real answer: 2022-12-07
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-08-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-06-01
# Real answer: 2021-03-17
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-28
# Real answer: 2022-09-28
# CORRECT
# ----------------------------------------------------
# Answer: 2019-08-02
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-10-20
# Real answer: 2022-10-20
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-16
# Real answer: 2021-09-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2006-05-19
# Real answer: 2006-05-19
# CORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2020-09-18
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-09-22
# Real answer: 2022-09-22
# CORRECT
# ----------------------------------------------------
# Answer: 2020-08-26
# Real answer: 2020-08-26
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2021-01-18
# Real answer: 2021-01-18
# CORRECT
# ----------------------------------------------------
# Answer: 2019-08-02
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Answer: 2019-11-02
# Real answer: 2017-02-02
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2020-07-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-02-23
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2024-04-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2019-12-16
# Real answer: 2019-12-16
# CORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2019-12-20
# INCORRECT
# ----------------------------------------------------
# Answer: 2016-05-01
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2021-12-21
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-12-21
# Real answer: 2021-12-21
# CORRECT
# ----------------------------------------------------
# Answer: 2015-10-01
# Real answer: 2015-10-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2015-04-26
# Real answer: 2015-04-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-03-01
# Real answer: 2023-02-14
# INCORRECT
# ----------------------------------------------------
# Answer: 2022-04-01
# Real answer: 2022-04-01
# CORRECT
# ----------------------------------------------------
# Answer: 2019-11-01
# Real answer: 2019-10-31
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2020-12-22
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-02-26
# Real answer: 2021-02-26
# CORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2018-01-29
# INCORRECT
# ----------------------------------------------------
# Answer: 1988-02-08
# Real answer: 1988-02-08
# CORRECT
# ----------------------------------------------------
# Answer: 2021-08-12
# Real answer: 2021-07-19
# INCORRECT
# ----------------------------------------------------
# Answer: 2023-10-01
# Real answer: 2020-01-01
# INCORRECT
# ----------------------------------------------------
# Answer: 2021-11-01
# Real answer: 2021-09-24
# INCORRECT
# ----------------------------------------------------
# Answer: 2020-03-30
# Real answer: 2020-03-30
# CORRECT
# ----------------------------------------------------
# Answer: 2020-02-01
# Real answer: 2020-01-09
# INCORRECT
# ----------------------------------------------------
# Answer: 2013-08-07
# Real answer: 2013-08-07
# CORRECT
# ----------------------------------------------------
# Accuracy: 0.3617021276595745
# Results saved to results/effective_date_prompt_tuning_v4.csv
